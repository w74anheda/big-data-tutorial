# %% [markdown]
# ### ACID
# <img src='../img/ACID-Properties.jpg'/>
# <div dir="rtl" style="text-align:right !important">
#
# Atomicity: این خاصیت که به خاصیت همه یا هیچ معروف است، می گوید که یک تراکنش یا باید به طور کامل اجرا شود یا خیر. برای مثال اگر در یک تراکنش (Transaction) شما سه عملیات مختلف انجام می دهید، یا هر سه از این عملیات باید تا پایان تراکنش انجام شوند یا هیچ کدام انجام نمی شوند. مثالی که در درس گذشته درباره بانک بیان کردیم را به خاطر بیاورید. اگر UPDATE اول انجام شد، حتما باید UPDATE دوم نیز انجام شود، چون این دو UPDATE در یک تراکنش هستند. اگر برای مثال بعد از UPDATE اول از حساب کاربری A، مشکلی در سیستم به وجود آمد (مثلا برق قطع شد)، سیستم باید بعد از اتصال دوباره، عملیات UPDATE اول را بازگردانی (Rollback) نماید. به این ترتیب هیچ کدام از دو UPDATE صورت نگرفته است.
#
# -------------------------------------------
#
# Consistency: برای درک درست مفهوم consistency یا همان سازگاری به همان مثال تراکنش های بانک در درس قبل بازمیگردیم. همان طور که میدانید، در یک سیستم حسابداری بانک، مجموعه پول های انتقالی بین بانک باید ثابت باشد. در نظر بگیرید که مثلا اگر ۵۰هزار تومان از حساب کاربری A به حساب کاربری B منتقل شد، مجموعه پول های موجود در بانک تغییر نخواهد کرد. این همان مفهوم سازگاری است. یعنی یک تراکنش، پایگاه داده را از یک حالت سازگار به یک حالت سازگار دیگر انتقال می دهد. البته ممکن است این سازگاری در بین تراکنش (وقتی هنوز تراکنش تمام نشده است) نقض شود. در همان مثال قبل، حتما میدانید که بعد از کم شدن ۵۰هزار تومان از حساب کاربری A در پایگاه داده ( وقبل از واریز به حساب کاربری B)، در یک لحظه، consistency نقض می شود، ولی اشکالی ندارد، زیرا در پایان تراکنش همه چیز به حالت سازگار بازمیگردد.
#
# -------------------------------------------
#
# Isolation: فرض کنید در یک پایگاه داده، چندین تراکنش با یکدیگر در حال اجرا هستند. این تراکنش ها نباید از اجرای یک دیگر مطلع شوند. یعنی این تراکنش ها باید طوری اجرا شوند که انگار، فقط همین تراکنش در حال اجرا در کل پایگاه داده است.
#
# -------------------------------------------
#
# Durability: این مفهوم شاید ساده ترین خاصیت ACID باشد. Durability یا پایداری، به این معناست که یک تراکنش بعد از اتمام، باید در حافظه باقی بماند. یعنی اگر یک تراکنش با موفقیت به اتمام رسید، نتایج کار، با قطع برق یا اتفاق های دیگر از بین نرود.
#
# سوالی که مطرح می شود این است که کدام پایگاه داده های موجود از ACID پشتیبانی میکنند. یعنی کدام پایگاه داده های امروزی تراکنش هایشان، خاصیت ACID دارند؟ پایگاه داده های SQL SERVER، MYSql، Oracle و این دست از پایگاه داده ها، تماماً ACID را پشتیبانی می کنند.
#
# در واقع خاصیت ACID این امکان را می دهد که پایگاه داده ها، به صورت جامع با حفظ سازگاری (مثال بانک)، به صورت مطمئن اجرا شوند. معمولا این پایگاه داده ها، خرابی های موجود در سیستم را ترمیم می کنند و یا هنگامی که چندین کاربر به صورت همزمان قصد تغییر در یک رکورد خاص را داشته باشند، این پایگاه داده ها (که از ACID پشتیبانی میکنند) به صورت ۱۰۰٪ تضمین انجام عملیات درست را می دهند.
#
# البته در بسیاری از مسائل دنیای واقعی، پایگاه داده هایی با خاصیت ACID نیاز نمی باشد. زیرا پیاده سازی ACID باعث هزینه ی بالای پردازش و به تبع آن، کاهش سرعت در برخی از عملیات پایگاه داده ها می شود. برای همین، بسیاری از پایگاه داده هایی مانند No-SQLها، به طور کامل، ACID را پشتیبانی نمی کنند. این کار به سرعت بالای این دسته از پایگاه داده ها، کمک شایانی میکند و پیچیدگی پیاده سازی را کاهش می دهد.
# </div>
#
#
#
# ### Cap
# <img src='../img/cap.png'/>
# <img src='../img/Screenshot from 2023-04-09 21-18-35.png'/>
# <img src='../img/Screenshot from 2023-04-18 13-03-15.png'/>
# <img src='../img/rrr1.png'/>
# <img src='../img/rrr2.png'/>
# <img src='../img/rrr3.png'/>
# <img src='../img/rrr4.png'/>

# %% [markdown]
# # Redis
#
# ```
#  - redis-cli
#  - auth my_password
#  - ping : pong
#
#  String:
#  - set key:value EX second NX(run if not exist)| XX(run if exist) GET
#  - mset key1 value1 key2 value 2
#  - get key
#  - mget key1 key2
#  - incr key => if integer increment one
#  - incrby key count
#  - decr key
#  - decrby key
#
#  Hash:
#  - HSET key attr1 val1 attr2 val2
#  - HGET key attr2
#  - HGETALL key
#  - HDEL key attr2
#  - HINCRBY attr2 5
#  - HINCRBYFLOAT attr2 5
#  - HLEN key => return count of fileds in hash
#  - HVALS key => return all values
#  - HKEYS key => return all keys
#
#  List:
#  - lpush key 01 02 03
#  - rpush key 04
#  - lrange key 0 -1
#  - lpop key
#  - rpop key
#  - llen key
#
#  Set:(no duplicate)(unordered)
#  - SADD key val1 val2 val3
#  - SRANDMEMBER key
#
#  Sorted Sets:(no duplicate)(ordered)
#  - ZADD key order value
#  - ZRANGE users 0 -1 withscores
#
#  HyperLogLog:
#  - PFADD searchedkey val1 val2
#  - PFCOUNT searchedkey
#
#  Other:
#  - persist key (no expire)
#  - keys pattern(*reg* or *)
#  - del key
#  - getset key new value ==> return old value and update to new value
#  - strlen key => return value length of key
#
#  PubSub:
#  - subscribe subject
#  - publish subject message
#
#
#  Transaction:
#  - atomic (not fully acid)
#  - multi
#      - set user masoud
#      - set pass 123
#      - incr pass
#    -exec
#
#
#  Pipeline:
#  Transactions vs Pipeline in Redis.
#  We have seen that pipeline is a way to send all commands together from the client-side, the same applies to Redis transactions as well, then how are they different?
#
#     The difference is pipelines are not atomic whereas transactions are atomic, meaning 2 transactions do not run at the same time, whereas multiple pipelines can be executed by Redis-server at the same time in an interleaved fashion.
#     URL: https://buildatscale.tech/what-is-redis-pipeline/
#
#
#
#
# ```
# ###-----------------------------------------------------------------------------------------------------
#
#
# ## Distributed:
#
#  - redis is Multi-Master-Multi-Slave
#  - each master should be has min one slave
#  - crc16 ---> 0-16384/master_count
#  - redis-cli --cluster create master master master slave slave slave
#  <img src='../img/Screenshot from 2023-03-08 10-15-15.png'/>
#
#
#
#
# - redis-cli --cluster create redis_master_1:6379 redis_master_2:6379 redis_master_3:6379 redis_master_1_slave_1:6379 redis_master_2_slave_1:6379 redis_master_3_slave_1:6379  --cluster-replicas 1
#
#
#  - redis-cli -c (auto redirect)
#
#
# ###-----------------------------------------------------------------------------------------------------
#
# ## Concurency: solve with : Transaction/LUA script
#
#
# <img src='../img/Screenshot from 2023-04-21 12-04-10.png'/>
# <img src='../img/Screenshot from 2023-04-21 18-48-46.png'/>
# <img src='../img/Screenshot from 2023-04-21 18-56-41.png'/>
# <img src='../img/Screenshot from 2023-04-21 18-58-51.png'/>
# <img src='../img/Screenshot from 2023-04-21 19-04-54.png'/>
#
# ###-----------------------------------------------------------------------------------------------------
# ## Lua Script (programmin language):
# <img src='../img/Screenshot from 2023-04-22 10-42-11.png'/>
#
# ```
#
# ### BASIC
#
#     local score = 4;
#     score = 6
#
#     if score ~= 4 and score < 10 then
#         print('win, is not equal to 4')
#     elseif  score == nil then
#         print('faild')
#     end
#
# ### ARRAY
#
#     local colors = {'red','blue','green'}
#     -- colors[1] //red
#     -- #colors // return count 3
#     table.insert(colors, 'orange')
#
#     for index, value in ipairs(colors) do
#         print(index, value)
#     end
#
# ### OBJECT (TABLE)
#
# for i=5, 10 do
#     print(i)
# end
#
# local user = {id = '202', name= 'masoud'}
# -- user['id']
#
# for key, value in pairs(user) do
#     print(key, value)
# end
#
# ```
# ### Run Lua with Redis
#
# <img src='../img/Screenshot from 2023-04-22 11-11-39.png'/>
#
#
#
# ```
# SCRIPT LOAD 'return ARGV[1] + tonumber(ARGV[2]) ' // return an Script_ID
# EVALSHA Script_ID 0 20 30 ===> ARGSV = {20, 30}
#
#
# SCRIPT LOAD 'return redis.call("GET", KEYS[1])'
# EVALSHA Script_ID 1 color ===> KEYS = {'color'}
#
#
# SCRIPT LOAD 'return redis.call("GET", KEYS[1])'
# EVALSHA Script_ID 2 color name  ===> KEYS = {'color', 'name'}
#
#
#
# SCRIPT LOAD 'return redis.call("GET", KEYS[1])'
# EVALSHA Script_ID 2 color name 20 30  ===> KEYS = {'color', name}, ARGSV = {20, 30}
#
#
# ```
#
# ## Concurency problem with watch
#
# <img src='../img/Screenshot from 2023-04-23 19-29-15.png'/>
# <img src='../img/Screenshot from 2023-04-23 19-35-16.png'/>
#
#
# <img src='../img/conc_1.png'/>
# ###***************************************************************************************
#
# <img src='../img/conc_2.png'/>
# ###***************************************************************************************
# <img src='../img/conc_3.png'/>
# ###***************************************************************************************
# <img src='../img/conc_4.png'/>
# ###***************************************************************************************
# <img src='../img/conc_5.png'/>
# ###***************************************************************************************
# <img src='../img/conc_6.png'/>
# ###***************************************************************************************
# <img src='../img/conc_7.png'/>
# ###***************************************************************************************
# <img src='../img/conc_8.png'/>
# ###***************************************************************************************
# <img src='../img/conc_9.png'/>
# ###***************************************************************************************
# <img src='../img/conc_10.png'/>
# ###***************************************************************************************
# <img src='../img/conc_11.png'/>
# ###***************************************************************************************
# <img src='../img/conc_12.png'/>
# ###***************************************************************************************
#
# NEW ISSUE WHENE retry
#
# <img src='../img/conc_13.png'/>
# <img src='../img/conc_14.png'/>
#
# ## for solve this issue is two way :
#     1 - create signal if lock token expire then exit code
#     2 - create connection proxy if lock token expire terminated connection
#
#
#
#
#
#
#
#
#
#
#
# ###***************************************************************************************
#
# ## Add Module to Redis (Search-json)
#
# <img src='../img/ml1.png'/>
# <img src='../img/ml2.png'/>
# <img src='../img/ml3.png'/>
# <img src='../img/ml4.png'/>
#
#
#
# ### Module 01 ===> Redis Search
#
#
# <img src='../img/search01.png'/>
# <img src='../img/search02.png'/>
# <img src='../img/search03.png'/>
#
# ```
#  - FT.CREATE
#  - FT.SEARCH
#  - FT.DROPINDEX
#  - FT.LIST
#
#  -
#     HSET cars#a1 name 'fast car' color red year 1950
#     HSET cars#b1 name 'car' color red year 1960
#     HSET cars#c1 name 'old car' color blue year 1970
#     HSET cars#d1 name 'new car' color blue year 1990
#
# -
#     FT.CREATE idx:cars ON HASH PREFIX 1 cars#
#         SCHEMA name TEXT color TAG year numeric
#
#     FT.CREATE idx:cars ON HASH PREFIX 2 cars# trucks#
#         SCHEMA name TEXT color TAG year numeric
#
#
# - FT.SEARCH idx:cars '@name:(fast car)'
# - FT.SEARCH idx:cars '@color:{red}'
# - FT.SEARCH idx:cars '@year:[1900 1970]'
# - FT.SEARCH idx:cars '@year:[1900 1970] @color:{red}'
#
#
#
#
# --- index filed types:
#     - TEXT ==> support fuzzy search, typos, ...
#     - TAG  ==> used for exact string lookup
#     - NUMBER
#     - GEO
#     - VECTOR
#
#
# --- query types (number / tag / text ):
# ```
# <img src='../img/ns1.png'/>
# <img src='../img/ns2.png'/>
# <img src='../img/tt1.png'/>
# <img src='../img/tt2.png'/>
# <img src='../img/tt3.png'/>
# <img src='../img/tt4.png'/>
# <img src='../img/tt5.png'/>
#
# ```
#
# ```
# --- fuzzy search
#
# <img src='../img/fff1.png'/>
# <img src='../img/fff2.png'/>
# <img src='../img/fff3.png'/>
# <img src='../img/fff4.png'/>
# <img src='../img/fff5.png'/>
# <img src='../img/fff6.png'/>
#
# --- prefix search
#
# <img src='../img/pp1.png'/>
#
#
# --- PreProcessing search
# <img src='../img/ppf1.png'/>
# <img src='../img/ppf2.png'/>
# <img src='../img/ppf3.png'/>
#
# --- TF/IDF Score and sort/limit search result
#
# <img src='../img/ssr1.png'/>
# <img src='../img/ssr2.png'/>
# <img src='../img/ssr3.png'/>
# <img src='../img/ssr4.png'/>
# <img src='../img/ssr5.png'/>
# <img src='../img/ssr6.png'/>
# <img src='../img/ssr7.png'/>
# <img src='../img/ssr8.png'/>
# <img src='../img/ssr9.png'/>
# <img src='../img/ssr10.png'/>
# <img src='../img/ssr11.png'/>
# <img src='../img/ssr12.png'/>
#
#
#
#
#
# ### STREAMS
#
#
# <img src='../img/stream_01.png'/>
# <img src='../img/stream_02.png'/>
# <img src='../img/stream_03.png'/>
# <img src='../img/stream_04.png'/>
# <img src='../img/stream_05.png'/>
# <img src='../img/stream_06.png'/>
# <img src='../img/stream_07.png'/>
# <img src='../img/stream_08.png'/>
# <img src='../img/stream_09.png'/>
# <img src='../img/stream_10.png'/>
# <img src='../img/stream_11.png'/>
# <img src='../img/stream_12.png'/>
# <img src='../img/stream_13.png'/>
# <img src='../img/stream_14.png'/>
# <img src='../img/stream_15.png'/>
# <img src='../img/stream_16.png'/>
# <img src='../img/stream_17.png'/>
# <img src='../img/stream_18.png'/>
# <img src='../img/stream_19.png'/>
# <img src='../img/stream_20.png'/>
# <img src='../img/stream_21.png'/>
# <img src='../img/stream_21.png'/>
# <img src='../img/stream_23.png'/>
# <img src='../img/stream_24.png'/>
# <img src='../img/stream_25.png'/>
# <img src='../img/stream_26.png'/>
# <img src='../img/stream_27.png'/>

# %% [markdown]
# ### Links:
# * [Play with docker](https://labs.play-with-docker.com/)
#
# ## Commands
#
#
# <img src='../img/Screenshot from 2023-03-10 11-39-41.png' />
# <img src='../img/Screenshot from 2023-03-10 12-48-55.png' />
# <img src='../img/Screenshot from 2023-03-12 21-32-08.png' />
#
#
#
# ```
#  - RUN ==> building time command
#  - CMD ==> runtime command
#  - docker image prune
#  - docker container prune
#  - docker build -t react-app:v1.0 .
#  - docker image tag react-app:latest m74asoud/react-app:v1.1
#
#  - docker compose down --rmi all
#  - build image :  docker build -t hello-docker-from-js .(dockerfile path)
#  - docker pull docker_image
#  - docker push m74asoud/docker_image
#  - pwd => current linux directory
#  - echo "console.log('hello docker')" > /app/app.js
#  - echo "console.log('hello docker')" >> /app/app.js
#  - mv /app/app.js /app/index.js
#  - ctrl + l
#  - ctrl + w
#  - head/tail/more/less/cat filename
#  - grep -i -r Hello app* ./dir
#  - find / file_or_directory_name
#  - find / -type f/d file_or_directory_name
#  - find / -type d -iname "sec*" (uncasesensitive)
#  - printenv PATH === echo $PATH
#  - export VAR_NAME=value ===> persist variable ===> echo DB_USER=value >> ~/.bashrc ===> source ~/.bashrc
#  - sleep 100 &
#  - kill psid
#  - cat /etc/passwd | grep maso*
#  - passwd newpassword
#  - usermod -s /bin/bash username
#  - cat /etc/shadow ==> passwords
#  - groupdadd developers
#  - groupmod
#  - groupdel
#  - usermod -G developers masoud
#  - groups masoud
#  - su - user ==> change user
#
#
#
#  Chaining commands:
#   - mkdir /app; cd /app; echo hello; (if each command failed another command worked)
#   - mkdir /app && cd /app && echo hello && (if each command failed another command failed)
#   - mkdir /app || echo directory exist (if first command failed next command is fire)
#   - ls /bin | grep *.py
#   - ls /bin | less
#
#   - mkdir /app;\
#     cd /app;\
#     cat app.js
#
#  Managing process:
#   - ps
#
# ```
#
#   - <img src='../img/filepermissions.png' width='100%'/>
#
# ```
#  File permissions:
#   chmod u(user)/g(group)/o(other) +/- x filename
#   chmode ugo+x+w-r filename
#
# ```
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 2:30:00
